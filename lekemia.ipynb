# %%
from sklearn.model_selection import train_test_split
import pandas as pd

df = pd.read_csv('/Users/shrilekha/Desktop/spring 2019/master project/leukemia_big.csv') #for an earlier version of Excel, you may need to use the file extension of 'xls'


df = df.rename(columns={"ALL": "0"})
df = df.rename(columns={"ALL.1": "0"})
df = df.rename(columns={"ALL.2": "0"})
df = df.rename(columns={"ALL.3": "0"})
df = df.rename(columns={"ALL.4": "0"})
df = df.rename(columns={"ALL.5": "0"})
df = df.rename(columns={"ALL.6": "0"})
df = df.rename(columns={"ALL.7": "0"})
df = df.rename(columns={"ALL.8": "0"})
df = df.rename(columns={"ALL.9": "0"})
df = df.rename(columns={"ALL.10": "0"})
df = df.rename(columns={"ALL.11": "0"})
df = df.rename(columns={"ALL.12": "0"})
df = df.rename(columns={"ALL.13": "0"})
df = df.rename(columns={"ALL.14": "0"})
df = df.rename(columns={"ALL.15": "0"})
df = df.rename(columns={"ALL.16": "0"})
df = df.rename(columns={"ALL.17": "0"})
df = df.rename(columns={"ALL.18": "0"})
df = df.rename(columns={"ALL.19": "0"})
df = df.rename(columns={"ALL.20": "0"})
df = df.rename(columns={"ALL.21": "0"})
df = df.rename(columns={"ALL.22": "0"})
df = df.rename(columns={"ALL.23": "0"})
df = df.rename(columns={"ALL.24": "0"})
df = df.rename(columns={"ALL.25": "0"})
df = df.rename(columns={"ALL.26": "0"})
df = df.rename(columns={"ALL.27": "0"})
df = df.rename(columns={"ALL.28": "0"})
df = df.rename(columns={"ALL.29": "0"})
df = df.rename(columns={"ALL.30": "0"})
df = df.rename(columns={"ALL.31": "0"})
df = df.rename(columns={"ALL.32": "0"})
df = df.rename(columns={"ALL.33": "0"})
df = df.rename(columns={"ALL.34": "0"})
df = df.rename(columns={"ALL.35": "0"})
df = df.rename(columns={"ALL.36": "0"})
df = df.rename(columns={"ALL.37": "0"})
df = df.rename(columns={"ALL.38": "0"})
df = df.rename(columns={"ALL.39": "0"})
df = df.rename(columns={"ALL.40": "0"})
df = df.rename(columns={"ALL.41": "0"})
df = df.rename(columns={"ALL.42": "0"})
df = df.rename(columns={"ALL.43": "0"})
df = df.rename(columns={"ALL.44": "0"})
df = df.rename(columns={"ALL.45": "0"})
df = df.rename(columns={"ALL.46": "0"})
df = df.rename(columns={"AML": "1"})
df = df.rename(columns={"AML.1": "1"})
df = df.rename(columns={"AML.2": "1"})
df = df.rename(columns={"AML.3": "1"})
df = df.rename(columns={"AML.4": "1"})
df = df.rename(columns={"AML.5": "1"})
df = df.rename(columns={"AML.6": "1"})
df = df.rename(columns={"AML.7": "1"})
df = df.rename(columns={"AML.8": "1"})
df = df.rename(columns={"AML.9": "1"})
df = df.rename(columns={"AML.10": "1"})
df = df.rename(columns={"AML.11": "1"})
df = df.rename(columns={"AML.12": "1"})
df = df.rename(columns={"AML.13": "1"})
df = df.rename(columns={"AML.14": "1"})
df = df.rename(columns={"AML.15": "1"})
df = df.rename(columns={"AML.16": "1"})
df = df.rename(columns={"AML.17": "1"})
df = df.rename(columns={"AML.18": "1"})
df = df.rename(columns={"AML.19": "1"})
df = df.rename(columns={"AML.20": "1"})
df = df.rename(columns={"AML.21": "1"})
df = df.rename(columns={"AML.22": "1"})
df = df.rename(columns={"AML.23": "1"})
df = df.rename(columns={"AML.24": "1"})
df

# This dataset has 7128 rows and 72 columns (denotes class labels) 
#among which 27 are type 1 leukaemia (acute lymphoblastic leu- kaemia) 
# and 11 are type 2 leukaemia (acute myeloid leukaemia).
# Out:
#              0         0         0         0         0         0         0  \
# 0    -1.533622 -0.867610 -0.433172 -1.671903 -1.187689 -1.127234 -1.045409
# 1    -1.235673 -1.275501 -1.184492 -1.596424 -1.335256 -1.113730 -0.800880
# 2    -0.333983  0.375927 -0.459196 -1.422571 -0.797493 -1.362768 -0.671954
# 3     0.488702  0.444011  0.436264  0.193353  0.235632 -0.360312  0.184941
# 4    -1.300893 -1.229660 -1.325882 -1.818329 -1.311206 -1.513975 -1.651624
# 5    -1.682668 -1.642072 -1.407264 -1.744469 -1.654381 -1.777619 -1.805620
# 6    -2.010995  0.572919 -0.264655 -1.793197 -1.441690  0.824113 -1.477915
# 7    -1.449186 -1.588304 -1.147713 -1.446178 -1.058556 -1.237939 -1.219243
# 8     0.035344  0.219574 -0.573541 -0.325815 -0.582683 -0.348518 -0.708994
# 9    -1.088905  0.119834  0.784512 -1.324191  0.001758 -0.399999 -1.101717
# 10   -0.301622  0.254654 -0.251931 -1.350852 -0.663166 -0.688126 -1.189114
# ...

# %%
# Splitting the data into test and train 
from sklearn.model_selection import train_test_split

import numpy as np

new_data = np.transpose(df)
label = new_data.index

# print(np.transpose(label).shape)
new_data["label"] = label
feautre = new_data.iloc[:,1:7128]

train,test =train_test_split(new_data,test_size=0.3,random_state=0) 
print(train.shape)
print(test.shape)

train_feature = train.iloc[:,1:7128]
train_label = train.iloc[:,7128]

test_feature = test.iloc[:,1:7128]
test_label = test.iloc[:,7128]
# Out:
# (50, 7129)
# (22, 7129)

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np

x_train = StandardScaler().fit_transform(train_feature)
x_test = StandardScaler().fit_transform(test_feature)

pca = PCA(n_components=10)
pca = pca.fit(x_train)
reduced_data = pca.fit_transform(x_train)
print(reduced_data.shape)

reduced_data_test = pca.fit_transform(x_test)
print(reduced_data_test.shape)

pca.explained_variance_ratio_


pca.n_components = 7128
percentage_var_explained = pca.explained_variance_ / np.sum(pca.explained_variance_);

cum_var_explained = np.cumsum(percentage_var_explained)

plt.figure(1, figsize=(8, 6))

plt.clf()
plt.plot(cum_var_explained, linewidth=2)
plt.axis('tight')
plt.grid()
plt.xlabel('n_components')
plt.ylabel('Cumulative_explained_variance')
plt.show()
# Out:
# (50, 10)
# (22, 10)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics 
import seaborn as sns
model_1 = LogisticRegression()
model_1.fit(train_feature,train_label) 
prediction_1=model_1.predict(test_feature) 
print('The accuracy of the Logistic Regression using all variables is:',metrics.accuracy_score(prediction_1,test_label))
cm1 = metrics.confusion_matrix(test_label, prediction_1)
print(cm1)

plt.figure(figsize=(2,2))
sns.heatmap(cm1, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
# Out:
# The accuracy of the Logistic Regression using all variables is: 0.9545454545454546
# [[11  0]
#  [ 1 10]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-233-c743cf40fd99> in <module>()
#      13 plt.ylabel('Actual label');
#      14 plt.xlabel('Predicted label');
# ---> 15 all_sample_title = 'Accuracy Score: {0}'.format(score)
#      16 plt.title(all_sample_title, size = 15);
#
# NameError: name 'score' is not defined

# %%
# Logistic regression on PCA dataset

model_1p = LogisticRegression()
model_1p.fit(reduced_data,train_label) 
prediction_1p=model_1p.predict(reduced_data_test) 
print('The accuracy of the Logistic Regression using all variables is:',metrics.accuracy_score(prediction_1p,test_label))
# Out:
# The accuracy of the Logistic Regression using all variables is: 0.7727272727272727

# %%
from sklearn.neighbors import KNeighborsClassifier 

model_3=KNeighborsClassifier(n_neighbors=2) 
model_3.fit(train_feature,train_label) 
prediction_3=model_3.predict(test_feature) 
print('The accuracy of the KNN using all variables is:',metrics.accuracy_score(prediction_3,test_label))
# Out:
# The accuracy of the KNN using all variables is: 0.8636363636363636

# %%
from sklearn.neighbors import KNeighborsClassifier 

model_3p=KNeighborsClassifier(n_neighbors=3) 
model_3p.fit(reduced_data,train_label) 
prediction_3p=model_3p.predict(reduced_data_test) 
print('The accuracy of the KNN using all variables is:',metrics.accuracy_score(prediction_3p,test_label))
# Out:
# The accuracy of the KNN using all variables is: 0.6818181818181818

# %%
from sklearn.neighbors import KNeighborsClassifier 

model_3p=KNeighborsClassifier(n_neighbors=3) 
model_3p.fit(reduced_data,train_label) 
prediction_3p=model_3p.predict(reduced_data_test) 
print('The accuracy of the KNN using all variables is:',metrics.accuracy_score(prediction_3p,test_label))

# %%
from sklearn import svm
model=svm.SVC()
model.fit(train_feature,train_label) 
prediction=model.predict(test_feature) 
print('The accuracy of the SVM using all variables is:',metrics.accuracy_score(prediction,test_label))
# Out:
# The accuracy of the SVM using all variables is: 0.6363636363636364

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import confusion_matrix 
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import timeit


start = timeit.default_timer()

C_range = [.001, 0.1,1,100,100000]
for i in C_range:
    model_4 = OneVsRestClassifier(SVC(kernel='poly',degree=3, C = i))
    clf_4 =  model_4.fit(train_feature,train_label)
    y_pred_4 = clf_4.predict(test_feature)
    accuracy_4 = accuracy_score(y_pred_4, test_label)
    print(accuracy_4)
    
end = timeit.default_timer()
# Out:
# 0.5
# 0.5
# 0.7727272727272727
# 0.9545454545454546
# 0.9545454545454546

# %%
from sklearn.metrics import classification_report, confusion_matrix  
from sklearn.svm import SVC  

gamma_range = [0.000001,0.00001,.0001, 0.001,1,100,100000]
for i in gamma_range:
    model_5 = SVC(kernel='rbf', gamma =i, C = 10000)  
    model_5.fit(train_feature,train_label)  
    y_pred_5 = model_5.predict(test_feature) 
    accuracy_5 = accuracy_score(y_pred_5, test_label)
    print(accuracy_5)
# Out:
# 0.9545454545454546
# 0.9545454545454546
# 0.9545454545454546
# 0.6363636363636364
# 0.5
# 0.5
# 0.5

# %%
import numpy as np

class NeuralNetwork():
    
    def __init__(self):
        # seeding for random number generation
        np.random.seed(1)
        
        #converting weights to a 3 by 1 matrix with values from -1 to 1 and mean of 0
        self.synaptic_weights = 2 * np.random.random((3, 1)) - 1

    def sigmoid(self, x):
        #applying the sigmoid function
        return 1 / (1 + np.exp(-x))

    def sigmoid_derivative(self, x):
        #computing derivative to the Sigmoid function
        return x * (1 - x)

    def train(self, training_inputs, training_outputs, training_iterations):
        
        #training the model to make accurate predictions while adjusting weights continually
        for iteration in range(training_iterations):
            #siphon the training data via  the neuron
            output = self.think(training_inputs)

            #computing error rate for back-propagation
            error = training_outputs - output
            
            #performing weight adjustments
            adjustments = np.dot(training_inputs.T, error * self.sigmoid_derivative(output))

            self.synaptic_weights += adjustments

    def think(self, inputs):
        #passing the inputs via the neuron to get output   
        #converting values to floats
        
        inputs = inputs.astype(float)
        output = self.sigmoid(np.dot(inputs, self.synaptic_weights))
        return output
    
if __name__ == "__main__":

    #initializing the neuron class
    neural_network = NeuralNetwork()

    print("Beginning Randomly Generated Weights: ")
    print(neural_network.synaptic_weights)

   
    
    #training taking place
    neural_network.train(train_feature,train_label, training_outputs, 15000)

    print("Ending Weights After Training: ")
    print(neural_network.synaptic_weights)

    #user_input_one = str(input("User Input One: "))
    #user_input_two = str(input("User Input Two: "))
    #user_input_three = str(input("User Input Three: "))
    
    #print("Considering New Situation: ", user_input_one, user_input_two, user_input_three)
    #print("New Output data: ")
    #print(neural_network.think(np.array([user_input_one, user_input_two, user_input_three])))
    #print("Wow, we did it!")
# Out:
# Beginning Randomly Generated Weights:
# [[-0.16595599]
#  [ 0.44064899]
#  [-0.99977125]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-184-ea766425243f> in <module>()
#      52
#      53     #training taking place
# ---> 54     neural_network.train(train_feature,train_label, training_outputs, 15000)
#      55
#      56     print("Ending Weights After Training: ")
#
# NameError: name 'training_outputs' is not defined

# %%
# Elastic net
from sklearn.model_selection import cross_val_score
from itertools import product

def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, train_feature, train_label, scoring="mean_squared_error", cv = 5))
    return(rmse)


alphas = [0.0005, 0.001, 0.01, 0.03, 0.05, 0.1]
l1_ratios = [1.5, 1.1, 1, 0.9, 0.8, 0.7, 0.5]

cv_elastic = [rmse_cv(ElasticNet(alpha = alpha, l1_ratio=l1_ratio)).mean() 
            for (alpha, l1_ratio) in product(alphas, l1_ratios)]
# Out:
# /Users/shrilekha/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# /Users/shrilekha/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /Users/shrilekha/anaconda3/lib/python3.6/site-packages/sklearn/metrics/scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# ...

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
idx = list(product(alphas, l1_ratios))
p_cv_elastic = pd.Series(cv_elastic, index = idx)
p_cv_elastic.plot(title = "Validation - Just Do It")
plt.xlabel("alpha - l1_ratio")
plt.ylabel("rmse")
# Out:
# Text(0,0.5,'rmse')

# %%
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)
idx = list(product(alphas, l1_ratios))[:10]
p_cv_elastic = pd.Series(cv_elastic[:10], index = idx)
p_cv_elastic.plot(title = "Validation - Just Do It")
plt.xlabel("alpha - l1_ratio")
plt.ylabel("rmse")
# Out:
# Text(0,0.5,'rmse')

# %%
from sklearn.linear_model import ElasticNet

elastic = ElasticNet(random_state=0, alpha = 0.5)
elastic.fit(train_feature,train_label)

print(elastic.coef_) 

print(elastic.intercept_)
# Out:
# [ 0.  0.  0. ... -0.  0.  0.]
# 0.30594555513968047
